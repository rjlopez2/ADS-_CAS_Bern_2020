# %%
import pandas as pd
import os

# %%
file_path = os.path.abspath('.') + '/' + "HRD_COMPLETE_CODING_SHEET_WITH_NOTES.xlsx"
file_path
# Out:
# '/Users/rubencito/CAS_datascience/ADS_CAS_Bern_2020/Projects/M3/Vale_data/raw_files_dataset/HRD_COMPLETE_CODING_SHEET_WITH_NOTES.xlsx'

# %%
raw_df = pd.read_excel(file_path, 
                       header = [0], 
                       skiprows = [1],
                       usecols = [0, 3, 4, 7, 11],
                       parse_dates = [2, 3])
raw_df.head()
# Out:
#   Country name                                       Regime name   \
# 0         Peru                                Viceroyalty of Peru
# 1        Peru                 Interim government of Simon Bolivar
# 2        Peru   Liberal Congressional leaders/General La Mar a...
# 3         Peru                           Gamarra administration I
# 4         Peru  Liberal Congressional leaders/ Orbegoso admini...
#
#   v3regstartdate v3regenddate v3regendtype
# 0     13/01/1750   09/12/1824            5
# 1     09/12/1824   04/01/1827           12
# 2     04/01/1827   01/09/1829            0
# 3     01/09/1829   24/04/1834           11
# 4     24/04/1834   23/02/1835            0

# %%
raw_df.tail()
# Out:
#              Country name                                       Regime name   \
# 2075  Palestine/West Bank                  Jordanian occupation of West Bank
# 2076  Palestine/West Bank                                POLITY NON-EXISTENT
# 2077  Palestine/West Bank                                         Coding gap
# 2078  Palestine/West Bank  Palestine under the authority of the Palestini...
# 2079  Palestine/West Bank                             West Bank under Fatah
#
#            v3regstartdate         v3regenddate v3regendtype
# 2075  1948-05-14 00:00:00  1950-04-24 00:00:00           10
# 2076  1950-04-24 00:00:00  1950-12-31 00:00:00          NaN
# 2077  1950-12-31 00:00:00  1967-06-05 00:00:00          NaN
# 2078  1967-06-05 00:00:00  2007-06-15 00:00:00            5
# 2079  2007-06-15 00:00:00                    E          NaN

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2080 entries, 0 to 2079
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country name    2078 non-null   object
#  1   Regime name     2080 non-null   object
#  2   v3regstartdate  2080 non-null   object
#  3   v3regenddate    2080 non-null   object
#  4   v3regendtype    1873 non-null   object
# dtypes: object(5)
# memory usage: 81.4+ KB

# %%
raw_df[raw_df['v3regenddate'] ==  '09/12/1824']
# Out:
#   Country name  V-Dem code  Regime nr         Regime name  v3regstartdate  \
# 0         Peru        30.0        NaN  Viceroyalty of Peru     13/01/1750
#
#    Unnamed: 5                            Notes to v3regstartdate v3regenddate  \
# 0         1.0  The 256-year-old Treaty of Tordesillas was sup...   09/12/1824
#
#                                Notes to v3regenddate v3regendtypeMS  \
# 0  Peruvian independence declared on 28 July 1821...              5
#
#                              notes to v3regendtypeMS v3regendtype  \
# 0  Considered popular uprising in which Peru gain...            5
#
#   Notes to v3regendtype                         Sources  Interregnum  \
# 0                   NaN  Britannica; Pike (1967: 59-60)          0.0
#
#   Type interregnum Notes interregnum Coder  \
# 0              NaN               NaN    KS
#
#   Notes on alternative codings of regime spells counted as one/multiple regime  \
# 0                                                NaN
#
# ...

# %%
raw_df['start_year'] = 2020
raw_df.head(5)
# Out:
#   Country name  V-Dem code  Regime nr  \
# 0         Peru        30.0        NaN
# 1        Peru         30.0        NaN
# 2        Peru         30.0        NaN
# 3         Peru        30.0        NaN
# 4         Peru        30.0        NaN
#
#                                         Regime name  v3regstartdate  \
# 0                                Viceroyalty of Peru     13/01/1750
# 1                Interim government of Simon Bolivar     09/12/1824
# 2  Liberal Congressional leaders/General La Mar a...     04/01/1827
# 3                           Gamarra administration I     01/09/1829
# 4  Liberal Congressional leaders/ Orbegoso admini...     24/04/1834
#
#    Unnamed: 5                            Notes to v3regstartdate v3regenddate  \
# 0         1.0  The 256-year-old Treaty of Tordesillas was sup...   09/12/1824
# 1         0.0  Congress gives Bolivar continued power to atte...   04/01/1827
# 2         0.0  A new Congress convenes on 4 June 1827 were th...   01/09/1829
# ...

# %%
raw_df.shape
# Out:
# (2080, 21)

# %%
str(raw_df[['v3regenddate']])
# Out:
# '             v3regenddate\n0              09/12/1824\n1              04/01/1827\n2              01/09/1829\n3              24/04/1834\n4              23/02/1835\n...                   ...\n2075  1950-04-24 00:00:00\n2076  1950-12-31 00:00:00\n2077  1967-06-05 00:00:00\n2078  2007-06-15 00:00:00\n2079                    E\n\n[2080 rows x 1 columns]'

# %%
text = open('HRD_countryyear.csv', 'r')

# %%
text = ''.join([i for i in text]) \
    .replace('"', "")
x = open("HRD_countryyear_clean.csv","w")
x.writelines(text)
x.close()

# %%
pd.read_csv(os.path.abspath('.') + '/' + 'HRD_countryyear_clean.csv', usecols = [0])
# Out:
# /Users/rubencito/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             country.name
# Peru    30           NaN
#         30           NaN
#         30           NaN
#         30           NaN
#         30           NaN
# ...                  ...
# Tuscany 242          NaN
#         242          NaN
#         242          NaN
#         242          NaN
#         242          NaN
#
# [37444 rows x 1 columns]
